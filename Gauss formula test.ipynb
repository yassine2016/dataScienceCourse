# %% [markdown]
# ##this is to test the ability to create a Jupiter notebook in WS, save and share

# %%
def gauss(n):
    return(n*(n+1))/2

gauss(100)==sum(range(101))
# Out:
# True

# %% [markdown]
# |Gene|Coverage|VAF|Reportability|
# |----|--------|---|-------------|
# |BRAF|800|.23|Yes|
# |KRAS|450|.15|Yes|
# |ERBB2|1010|.33|Yes|
